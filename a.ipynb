# %%
import pandas as pd

erm = pd.read_parquet("outputs/erm/test_preds.parquet")
print("Columns:", erm.columns.tolist())
print("Shape:", erm.shape)
print(erm.head(3))
# Out:
# Columns: ['comment_text', 'y', 'group_id', 'asian_flag', 'black_flag', 'latino_flag', 'white_flag', 'male_flag', 'female_flag', 'other_gender_flag', 'christian_flag', 'muslim_flag', 'jewish_flag', 'hindu_flag', 'buddhist_flag', 'atheist_flag', 'other_religion_flag', 'bisexual_flag', 'heterosexual_flag', 'homosexual_gay_or_lesbian_flag', 'other_sexual_orientation_flag', 'psychiatric_or_mental_illness_flag', 'intellectual_or_learning_disability_flag', 'physical_disability_flag', 'other_disability_flag', 'other_race_or_ethnicity_flag', 'logit0', 'logit1', 'prob']
# Shape: (20000, 29)
#                                         comment_text  y  group_id  asian_flag  \
# 0  The AR family is ergonomic, handy, reliable an...  0        46           0
# 1  It's very clear that the United Nations is not...  0        46           0
# 2  This was the first thought that crossed my min...  0        46           0
#
#    black_flag  latino_flag  white_flag  male_flag  female_flag  \
# ...
